# %%
import numpy as np
import nltk

f = open('C:/Users/nda/Documents/GitHub/aidev/Meeting 25/sentence.txt', 'r', errors = 'ignore')
raw_code = f.read()
raw_code
# Out:
# 'Kim Chaewon is a highly talented South Korean singer and the charismatic leader of the popular K-pop girl group LE SSERAFIM. Before her debut with LE SSERAFIM in 2022, she gained widespread recognition and a dedicated global fanbase as a member of the project group IZ*ONE. Known for her distinctive, honey-like vocal tone and sharp dancing skills, she consistently delivers captivating performances on stage. Offstage, her bright personality and iconic short haircut have made her a prominent fashion icon and a favorite among fans worldwide.'

# %%
raw_code = raw_code.lower()
raw_code
# Out:
# 'kim chaewon is a highly talented south korean singer and the charismatic leader of the popular k-pop girl group le sserafim. before her debut with le sserafim in 2022, she gained widespread recognition and a dedicated global fanbase as a member of the project group iz*one. known for her distinctive, honey-like vocal tone and sharp dancing skills, she consistently delivers captivating performances on stage. offstage, her bright personality and iconic short haircut have made her a prominent fashion icon and a favorite among fans worldwide.'

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt_tab')
nltk.download('punkt')
nltk.download('wordnet')

segment = nltk.sent_tokenize(raw_code)
word_tokens = nltk.word_tokenize(raw_code)
segment
word_tokens
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\nda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nda\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['kim',
#  'chaewon',
#  'is',
#  'a',
#  'highly',
#  'talented',
#  'south',
#  'korean',
#  'singer',
#  'and',
#  'the',
#  'charismatic',
#  'leader',
#  'of',
#  'the',
#  'popular',
#  'k-pop',
#  'girl',
#  'group',
#  'le',
#  'sserafim',
#  '.',
#  'before',
#  'her',
#  'debut',
#  'with',
#  'le',
#  'sserafim',
#  'in',
#  '2022',
#  ',',
#  'she',
#  'gained',
#  'widespread',
#  'recognition',
#  'and',
#  'a',
#  'dedicated',
#  'global',
#  'fanbase',
#  'as',
#  'a',
#  'member',
#  'of',
#  'the',
#  'project',
#  'group',
#  'iz',
#  '*',
#  'one',
#  '.',
#  'known',
#  'for',
#  'her',
#  'distinctive',
#  ',',
#  'honey-like',
#  'vocal',
#  'tone',
#  'and',
#  'sharp',
#  'dancing',
#  'skills',
#  ',',
#  'she',
#  'consistently',
#  'delivers',
#  'captivating',
#  'performances',
#  'on',
#  'stage',
#  '.',
#  'offstage',
#  ',',
#  'her',
#  'bright',
#  'personality',
#  'and',
#  'iconic',
#  'short',
#  'haircut',
#  'have',
#  'made',
#  'her',
#  'a',
#  'prominent',
#  'fashion',
#  'icon',
#  'and',
#  'a',
#  'favorite',
#  'among',
#  'fans',
#  'worldwide',
#  '.']
