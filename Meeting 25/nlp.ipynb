# %%
import numpy as np
import nltk

f = open('C:/Users/nda/Documents/GitHub/aidev/Meeting 25/sentence.txt', 'r', errors = 'ignore')
raw_code = f.read()
raw_code
# Out:
# 'Kim Chaewon is a highly talented South Korean singer and the charismatic leader of the popular K-pop girl group LE SSERAFIM. Before her debut with LE SSERAFIM in 2022, she gained widespread recognition and a dedicated global fanbase as a member of the project group IZ*ONE. Known for her distinctive, honey-like vocal tone and sharp dancing skills, she consistently delivers captivating performances on stage. Offstage, her bright personality and iconic short haircut have made her a prominent fashion icon and a favorite among fans worldwide.'

# %%
raw_code = raw_code.lower()
raw_code
# Out:
# 'kim chaewon is a highly talented south korean singer and the charismatic leader of the popular k-pop girl group le sserafim. before her debut with le sserafim in 2022, she gained widespread recognition and a dedicated global fanbase as a member of the project group iz*one. known for her distinctive, honey-like vocal tone and sharp dancing skills, she consistently delivers captivating performances on stage. offstage, her bright personality and iconic short haircut have made her a prominent fashion icon and a favorite among fans worldwide.'

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt_tab')
nltk.download('punkt')
nltk.download('wordnet')

segment = nltk.sent_tokenize(raw_code)
word_tokens = nltk.word_tokenize(raw_code)
segment
word_tokens
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\nda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nda\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['kim',
#  'chaewon',
#  'is',
#  'a',
#  'highly',
#  'talented',
#  'south',
#  'korean',
#  'singer',
#  'and',
#  'the',
#  'charismatic',
#  'leader',
#  'of',
#  'the',
#  'popular',
#  'k-pop',
#  'girl',
#  'group',
#  'le',
#  'sserafim',
#  '.',
#  'before',
#  'her',
#  'debut',
#  'with',
#  'le',
#  'sserafim',
#  'in',
#  '2022',
#  ',',
#  'she',
#  'gained',
#  'widespread',
#  'recognition',
#  'and',
#  'a',
#  'dedicated',
#  'global',
#  'fanbase',
#  'as',
#  'a',
#  'member',
#  'of',
#  'the',
#  'project',
#  'group',
#  'iz',
#  '*',
#  'one',
#  '.',
#  'known',
#  'for',
#  'her',
#  'distinctive',
#  ',',
#  'honey-like',
#  'vocal',
#  'tone',
#  'and',
#  'sharp',
#  'dancing',
#  'skills',
#  ',',
#  'she',
#  'consistently',
#  'delivers',
#  'captivating',
#  'performances',
#  'on',
#  'stage',
#  '.',
#  'offstage',
#  ',',
#  'her',
#  'bright',
#  'personality',
#  'and',
#  'iconic',
#  'short',
#  'haircut',
#  'have',
#  'made',
#  'her',
#  'a',
#  'prominent',
#  'fashion',
#  'icon',
#  'and',
#  'a',
#  'favorite',
#  'among',
#  'fans',
#  'worldwide',
#  '.']

# %%
import re
clean_data = []
for words in word_tokens:
    item = []
    result = re.sub(r"[^\w\s]", "", words)
    if result != "":
        clean_data.append(result)

clean_data
# Out:
# ['kim',
#  'chaewon',
#  'is',
#  'a',
#  'highly',
#  'talented',
#  'south',
#  'korean',
#  'singer',
#  'and',
#  'the',
#  'charismatic',
#  'leader',
#  'of',
#  'the',
#  'popular',
#  'kpop',
#  'girl',
#  'group',
#  'le',
#  'sserafim',
#  'before',
#  'her',
#  'debut',
#  'with',
#  'le',
#  'sserafim',
#  'in',
#  '2022',
#  'she',
#  'gained',
#  'widespread',
#  'recognition',
#  'and',
#  'a',
#  'dedicated',
#  'global',
#  'fanbase',
#  'as',
#  'a',
#  'member',
#  'of',
#  'the',
#  'project',
#  'group',
#  'iz',
#  'one',
#  'known',
#  'for',
#  'her',
#  'distinctive',
#  'honeylike',
#  'vocal',
#  'tone',
#  'and',
#  'sharp',
#  'dancing',
#  'skills',
#  'she',
#  'consistently',
#  'delivers',
#  'captivating',
#  'performances',
#  'on',
#  'stage',
#  'offstage',
#  'her',
#  'bright',
#  'personality',
#  'and',
#  'iconic',
#  'short',
#  'haircut',
#  'have',
#  'made',
#  'her',
#  'a',
#  'prominent',
#  'fashion',
#  'icon',
#  'and',
#  'a',
#  'favorite',
#  'among',
#  'fans',
#  'worldwide']

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords

print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nda\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
clean_data_1 = []
for words in clean_data:
    if not words in stopwords.words('english'):
        clean_data_1.append(words)

clean_data_1
# Out:
# ['kim',
#  'chaewon',
#  'highly',
#  'talented',
#  'south',
#  'korean',
#  'singer',
#  'charismatic',
#  'leader',
#  'popular',
#  'kpop',
#  'girl',
#  'group',
#  'le',
#  'sserafim',
#  'debut',
#  'le',
#  'sserafim',
#  '2022',
#  'gained',
#  'widespread',
#  'recognition',
#  'dedicated',
#  'global',
#  'fanbase',
#  'member',
#  'project',
#  'group',
#  'iz',
#  'one',
#  'known',
#  'distinctive',
#  'honeylike',
#  'vocal',
#  'tone',
#  'sharp',
#  'dancing',
#  'skills',
#  'consistently',
#  'delivers',
#  'captivating',
#  'performances',
#  'stage',
#  'offstage',
#  'bright',
#  'personality',
#  'iconic',
#  'short',
#  'haircut',
#  'made',
#  'prominent',
#  'fashion',
#  'icon',
#  'favorite',
#  'among',
#  'fans',
#  'worldwide']

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmed_data = [stemmer.stem(word) for word in clean_data_1]
stemmed_data
# Out:
# ['kim',
#  'chaewon',
#  'highli',
#  'talent',
#  'south',
#  'korean',
#  'singer',
#  'charismat',
#  'leader',
#  'popular',
#  'kpop',
#  'girl',
#  'group',
#  'le',
#  'sserafim',
#  'debut',
#  'le',
#  'sserafim',
#  '2022',
#  'gain',
#  'widespread',
#  'recognit',
#  'dedic',
#  'global',
#  'fanbas',
#  'member',
#  'project',
#  'group',
#  'iz',
#  'one',
#  'known',
#  'distinct',
#  'honeylik',
#  'vocal',
#  'tone',
#  'sharp',
#  'danc',
#  'skill',
#  'consist',
#  'deliv',
#  'captiv',
#  'perform',
#  'stage',
#  'offstag',
#  'bright',
#  'person',
#  'icon',
#  'short',
#  'haircut',
#  'made',
#  'promin',
#  'fashion',
#  'icon',
#  'favorit',
#  'among',
#  'fan',
#  'worldwid']

# %%
from nltk.stem.wordnet import WordNetLemmatizer
import nltk
lemmer = nltk.stem.WordNetLemmatizer()
nltk.download('wordnet')
lemma_data = []
for word in clean_data_1:
    lemma_data.append(lemmer.lemmatize(word))

lemma_data
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nda\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['kim',
#  'chaewon',
#  'highly',
#  'talented',
#  'south',
#  'korean',
#  'singer',
#  'charismatic',
#  'leader',
#  'popular',
#  'kpop',
#  'girl',
#  'group',
#  'le',
#  'sserafim',
#  'debut',
#  'le',
#  'sserafim',
#  '2022',
#  'gained',
#  'widespread',
#  'recognition',
#  'dedicated',
#  'global',
#  'fanbase',
#  'member',
#  'project',
#  'group',
#  'iz',
#  'one',
#  'known',
#  'distinctive',
#  'honeylike',
#  'vocal',
#  'tone',
#  'sharp',
#  'dancing',
#  'skill',
#  'consistently',
#  'delivers',
#  'captivating',
#  'performance',
#  'stage',
#  'offstage',
#  'bright',
#  'personality',
#  'iconic',
#  'short',
#  'haircut',
#  'made',
#  'prominent',
#  'fashion',
#  'icon',
#  'favorite',
#  'among',
#  'fan',
#  'worldwide']

# %%
nltk.download('averaged_perceptron_tagger_eng')
pos_data = nltk.pos_tag(lemma_data)
pos_data
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\nda\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [('kim', 'NNS'),
#  ('chaewon', 'VBD'),
#  ('highly', 'RB'),
#  ('talented', 'VBN'),
#  ('south', 'JJ'),
#  ('korean', 'JJ'),
#  ('singer', 'NN'),
#  ('charismatic', 'JJ'),
#  ('leader', 'NN'),
#  ('popular', 'JJ'),
#  ('kpop', 'NNP'),
#  ('girl', 'NN'),
#  ('group', 'NN'),
#  ('le', 'VBD'),
#  ('sserafim', 'JJ'),
#  ('debut', 'NN'),
#  ('le', 'VBZ'),
#  ('sserafim', 'JJ'),
#  ('2022', 'CD'),
#  ('gained', 'VBD'),
#  ('widespread', 'JJ'),
#  ('recognition', 'NN'),
#  ('dedicated', 'VBN'),
#  ('global', 'JJ'),
#  ('fanbase', 'NN'),
#  ('member', 'NN'),
#  ('project', 'NN'),
#  ('group', 'NN'),
#  ('iz', 'VBZ'),
#  ('one', 'CD'),
#  ('known', 'VBN'),
#  ('distinctive', 'JJ'),
#  ('honeylike', 'NN'),
#  ('vocal', 'JJ'),
#  ('tone', 'NN'),
#  ('sharp', 'JJ'),
#  ('dancing', 'NN'),
#  ('skill', 'NN'),
#  ('consistently', 'RB'),
#  ('delivers', 'VBZ'),
#  ('captivating', 'VBG'),
#  ('performance', 'NN'),
#  ('stage', 'NN'),
#  ('offstage', 'NN'),
#  ('bright', 'JJ'),
#  ('personality', 'NN'),
#  ('iconic', 'JJ'),
#  ('short', 'JJ'),
#  ('haircut', 'NN'),
#  ('made', 'VBD'),
#  ('prominent', 'JJ'),
#  ('fashion', 'NN'),
#  ('icon', 'IN'),
#  ('favorite', 'JJ'),
#  ('among', 'IN'),
#  ('fan', 'JJ'),
#  ('worldwide', 'NN')]

# %%
# !py -3.12 -m pip install --upgrade pip
# !py -3.12 -m pip install svgling
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')

from nltk import ne_chunk
import nltk

words = nltk.word_tokenize(raw_code)
pos_data = nltk.pos_tag(words)

tagged_tokens = ne_chunk(pos_data)
tagged_tokens
# Out:
# Requirement already satisfied: pip in C:\Users\nda\AppData\Local\Python\pythoncore-3.12-64\Lib\site-packages (26.1.2)
# Requirement already satisfied: svgling in C:\Users\nda\AppData\Local\Python\pythoncore-3.12-64\Lib\site-packages (0.5.0)
# Requirement already satisfied: svgwrite in C:\Users\nda\AppData\Local\Python\pythoncore-3.12-64\Lib\site-packages (from svgling) (1.4.3)
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\nda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\nda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# Tree('S', [('kim', 'NN'), ('chaewon', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('highly', 'RB'), ('talented', 'VBN'), ('south', 'JJ'), ('korean', 'JJ'), ('singer', 'NN'), ('and', 'CC'), ('the', 'DT'), ('charismatic', 'JJ'), ('leader', 'NN'), ('of', 'IN'), ('the', 'DT'), ('popular', 'JJ'), ('k-pop', 'JJ'), ('girl', 'NN'), ('group', 'NN'), ('le', 'VBD'), ('sserafim', 'NN'), ('.', '.'), ('before', 'IN'), ('her', 'PRP$'), ('debut', 'NN'), ('with', 'IN'), ('le', 'JJ'), ('sserafim', 'NN'), ('in', 'IN'), ('2022', 'CD'), (',', ','), ('she', 'PRP'), ('gained', 'VBD'), ('widespread', 'JJ'), ('recognition', 'NN'), ('and', 'CC'), ('a', 'DT'), ('dedicated', 'JJ'), ('global', 'JJ'), ('fanbase', 'NN'), ('as', 'IN'), ('a', 'DT'), ('member', 'NN'), ('of', 'IN'), ('the', 'DT'), ('project', 'NN'), ('group', 'NN'), ('iz', 'VBD'), ('*', 'NNP'), ('one', 'CD'), ('.', '.'), ('known', 'VBN'), ('for', 'IN'), ('her', 'PRP$'), ('distinctive', 'JJ'), (',', ','), ('honey-like', 'JJ'), ('vocal', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('sharp', 'JJ'), ('dancing', 'NN'), ('skills', 'NNS'), (',', ','), ('she', 'PRP'), ('consistently', 'RB'), ('delivers', 'VBZ'), ('captivating', 'VBG'), ('performances', 'NNS'), ('on', 'IN'), ('stage', 'NN'), ('.', '.'), ('offstage', 'NN'), (',', ','), ('her', 'PRP'), ('bright', 'JJ'), ('personality', 'NN'), ('and', 'CC'), ('iconic', 'JJ'), ('short', 'JJ'), ('haircut', 'NN'), ('have', 'VBP'), ('made', 'VBN'), ('her', 'PRP$'), ('a', 'DT'), ('prominent', 'JJ'), ('fashion', 'NN'), ('icon', 'NN'), ('and', 'CC'), ('a', 'DT'), ('favorite', 'JJ'), ('among', 'IN'), ('fans', 'NNS'), ('worldwide', 'VBP'), ('.', '.')])
